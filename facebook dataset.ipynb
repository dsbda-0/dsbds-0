# %%
import pandas as pd

# %%
df=pd.read_csv('dataset_Facebook.csv', sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.sample(7)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 127            136393   Photo         1          10             6         13
# 326            121540   Photo         2           5             7         14
# 394            107907   Photo         3           4             7         13
# 156            135700   Photo         2           9             2         11
# 427            100732   Photo         1           3             7         17
# 180            134879  Status         2           9             4          4
# 280            126345   Photo         2           6             1         12
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 127   0.0                        747                             1443
# 326   0.0                       3806                             6486
# 394   0.0                       4240                             7057
# 156   0.0                       3756                             7094
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
a = df.loc[0:9,['Page total likes','Type','Category']]
a
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3
# 3            139441   Photo         2
# 4            139441   Photo         2
# 5            139441  Status         2
# 6            139441   Photo         3
# 7            139441   Photo         3
# 8            139441  Status         2
# 9            139441   Photo         3

# %%
b = df.loc[0:9,['Type','Category','Post Month']]
b
# Out:
#      Type  Category  Post Month
# 0   Photo         2          12
# 1  Status         2          12
# 2   Photo         3          12
# 3   Photo         2          12
# 4   Photo         2          12
# 5  Status         2          12
# 6   Photo         3          12
# 7   Photo         3          12
# 8  Status         2          12
# 9   Photo         3          12

# %%
c = pd.concat([a,b])
c
# Out:
#    Page total likes    Type  Category  Post Month
# 0          139441.0   Photo         2         NaN
# 1          139441.0  Status         2         NaN
# 2          139441.0   Photo         3         NaN
# 3          139441.0   Photo         2         NaN
# 4          139441.0   Photo         2         NaN
# 5          139441.0  Status         2         NaN
# 6          139441.0   Photo         3         NaN
# 7          139441.0   Photo         3         NaN
# 8          139441.0  Status         2         NaN
# 9          139441.0   Photo         3         NaN
# 0               NaN   Photo         2        12.0
# 1               NaN  Status         2        12.0
# 2               NaN   Photo         3        12.0
# 3               NaN   Photo         2        12.0
# 4               NaN   Photo         2        12.0
# 5               NaN  Status         2        12.0
# 6               NaN   Photo         3        12.0
# 7               NaN   Photo         3        12.0
# ...

# %%
import numpy as np

# %%
d = df.sort_values(by=['Type'],ascending=False)
d
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 71             137893  Video         1          11             5          3
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 74             137893  Video         1          11             3         11
# 243            130791  Video         1           7             3         11
# ..                ...    ...       ...         ...           ...        ...
# 86             137177   Link         1          11             4          3
# 425            102112   Link         3           3             1          3
# 438             98195   Link         2           3             6          6
# 136            136393   Link         1          10             5         10
# 140            136013   Link         1          10             4          3
#
# ...
